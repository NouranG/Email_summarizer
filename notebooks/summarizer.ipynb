# %%
import imaplib
import email
import re
from bs4 import BeautifulSoup
import os
from dotenv import load_dotenv
from pathlib import Path
import sys

# %%
project_root=Path.cwd().parent
sys.path.append(str(project_root))

# %%
from src.config.settings import Settings

# %%
settings=Settings()

# %%
print(settings.model_name)
# Out:
# llama31:8b

# %%
from src.gmail.client import GmailClient,get_credentials
creds = get_credentials()
gmail_client = GmailClient(creds)
emails = gmail_client.list_messages()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=393612039667-ua4pddd0kasl42m3g5nnodmnc2euib55.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A56543%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.readonly&state=dwitGpwY7Zkib1rGqBonHuIuoyZ15e&code_challenge=bDpFc8tgEotJCzSSP1nnUkP20MH-xBB2Dy_OC7spZ7E&code_challenge_method=S256&access_type=offline

# %%
messages = []
for email in emails:
    msg = gmail_client.get_unread_messages()
    messages.append(msg)
